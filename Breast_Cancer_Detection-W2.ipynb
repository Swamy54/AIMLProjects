# %%
import numpy as np
import pandas as pd

# %%
# print first 5 rows of the dataset and mention what are the dependent and independent variables in the Data.

# %%
df=pd.read_csv(r"D:\AIML\Breast_Cancer_Detection_using_Machine_Learning_master\cancer dataset.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#### Step 2: Find the statistical parameters of the Data that you have

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
#### Step 3: Find the shape of the Dataset in hand.

# %%
df.shape
# Out:
# (569, 32)

# %%
#### Step 4: Find missing values from the Dataset

# %%
sum(df.isna().sum())
# Out:
# 0

# %%
#### Step 5: Find the value count of B(Benign) and M(Malignant) cancer cells in the column "diagnosis"

# %%
df["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#### Step 6: Creating a pairplot and mention the findings

# %%
df_dup=df.iloc[:,0:5]

# %%
df_dup
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean
# 0      842302         M       17.990         10.38          122.80
# 1      842517         M       20.570         17.77          132.90
# 2    84300903         M       19.690         21.25          130.00
# 3    84348301         M       11.420         20.38           77.58
# 4    84358402         M       20.290         14.34          135.10
# 5      843786         M       12.450         15.70           82.57
# 6      844359         M       18.250         19.98          119.60
# 7    84458202         M       13.710         20.83           90.20
# 8      844981         M       13.000         21.82           87.50
# 9    84501001         M       12.460         24.04           83.97
# 10     845636         M       16.020         23.24          102.70
# 11   84610002         M       15.780         17.89          103.60
# 12     846226         M       19.170         24.80          132.40
# ...

# %%
import seaborn as sns
sns.pairplot(df_dup, hue="diagnosis")

# %%
#### Step 7: Create a correlation matrix and mention strongly, weakly and negatively correlated quantities.

# %%
df_dup.corr(method="pearson")
# Out:
#                       id  radius_mean  texture_mean  perimeter_mean
# id              1.000000     0.074626      0.099770        0.073159
# radius_mean     0.074626     1.000000      0.323782        0.997855
# texture_mean    0.099770     0.323782      1.000000        0.329533
# perimeter_mean  0.073159     0.997855      0.329533        1.000000

# %%
There is no  negative correlation.
Radius_mean and Perimeter_mean are highly correlated.

# %%
### Step 8: Create a heatmap of the correlated features (helps in visualization)

# %%
sns.heatmap(df_dup.corr(), annot=True,fmt="0.0%")
